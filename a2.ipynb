# %% [markdown]
# # [Your Name] [Your ID]
# ## Data Science 201
# ## Assignment 2

# %%
# run this cell to define a list of data
# that will be used for the assignment
# !!! DO NOT MODIFY IT !!!

# the population of the town at index i of towns is at index i of populations
# towns[0] = "Westport, CT" and its population is populations[0] = 26391

# raw data
pop_data = [['Westport, CT', 26391], ['Fairfield, CT', 59404], ['Old Saybrook, CT', 10242], ['Springfield, MA', 153060], ['Thomaston, CT', 7887], ['Willington, CT', 6041], ['Cheshire, MA', 3235], ['Sturbridge, MA', 9268], ['Melrose, MA', 26983], ['Glastonbury, CT', 34427], ['Granville, MA', 1566], ['Exeter, RI', 6425], ['Colchester, CT', 16068], ['Erving, MA', 1800], ['Westerly, RI', 22787], ['Greenwich, CT', 61171], ['Suffield, CT', 15735], ['Sharon, CT', 2782], ['Douglas, MA', 8471], ['Egremont, MA', 1225], ['Chester, MA', 1337], ['Portsmouth, RI', 17389], ['North Adams, MA', 13708], ['Vernon, CT', 29179], ['Halifax, MA', 7518], ['Stonington, CT', 18545], ['Hopkinton, MA', 14925], ['Salisbury, CT', 3741], ['Winchester, CT', 11242], ['East Granby, CT', 5148], ['Smithfield, RI', 21430], ['East Windsor, CT', 11162], ['Woburn, MA', 38120], ['Westford, MA', 21951], ['Weston, MA', 11261], ['East Providence, RI', 47037], ['Waterbury, CT', 110366], ['Great Barrington, MA', 7104], ['Westfield, MA', 41094], ['Tewksbury, MA', 28961], ['Dracut, MA', 29457], ['Danbury, CT', 80893], ['Holliston, MA', 13547], ['Wendell, MA', 848], ['Abington, MA', 15985], ['Chatham, MA', 6125], ['New Haven, CT', 129779], ['Lakeville, MA', 10602], ['Sutton, MA', 8963], ['Bolton, MA', 4897], ['Maynard, MA', 10106], ['Warwick, MA', 780], ['Wakefield, MA', 24932], ['Franklin, CT', 1922], ['Plainfield, MA', 648], ['Mendon, MA', 5839], ['Glocester, RI', 9746], ['Everett, MA', 41667], ['Easthampton, MA', 16053], ['Union, CT', 854], ['Malden, MA', 59450], ['Washington, MA', 538], ['Ellington, CT', 15602], ['Pembroke, MA', 17837], ['Hancock, MA', 717], ['Salisbury, MA', 8283], ['Carlisle, MA', 4852], ['Somerville, MA', 75754], ['Bedford, MA', 13320], ['Randolph, MA', 32112], ['Wolcott, CT', 16680], ['Groveland, MA', 6459], ['Shelton, CT', 39559], ['Ashburnham, MA', 6081], ['Weymouth, MA', 53743], ['Enfield, CT', 44654], ['West Boylston, MA', 7669], ['Uxbridge, MA', 13457], ['Carver, MA', 11509], ['Belmont, MA', 24729], ['Danvers, MA', 26493], ['Savoy, MA', 692], ['Whately, MA', 1496], ['Becket, MA', 1779], ['Hingham, MA', 22157], ['Westhampton, MA', 1607], ['Cromwell, CT', 14005], ['North Andover, MA', 28352], ['Bristol, RI', 22954], ['Dalton, MA', 6756], ['Cummington, MA', 872], ['North Providence, RI', 32078], ['Westborough, MA', 18272], ['Medfield, MA', 12024], ['
Durham, CT', 7388], ['Lancaster, MA', 8055], ['Millville, MA', 3190], ['Somers, CT', 11444], ['Lanesborough, MA', 3091], ['Granby, MA', 6240], ['Harvard, MA', 6520], ['West Warwick, RI', 29191], ['Heath, MA', 706], ['Burlington, CT', 9301], ['Stoughton, MA', 26962], ['Mansfield, MA', 23184], ['Petersham, MA', 1234], ['West Hartford, CT', 63268], ['Darien, CT', 20732], ['Essex, CT', 6683], ['Beverly, MA', 39502], ['East Greenwich, RI', 13146], ['Hadley, MA', 5250], ['Hubbardston, MA', 4382], ['Tolland, CT', 15052], ['Madison, CT', 18269], ['Hanson, MA', 10209], ['Watertown, MA', 31915], ['Duxbury, MA', 15059], ['North Canaan, CT', 3315], ['Hampton, CT', 1863], ['Meriden, CT', 60868], ['Boxford, MA', 7965], ['Cohasset, MA', 7542], ['Newton, MA', 85146], ['Mattapoisett, MA', 6045], ['Hartland, CT', 2114], ['Huntington, MA', 2180], ['Richmond, MA', 1475], ['Winchester, MA', 21374], ['Guilford, CT', 22375], ['Hampden, MA', 5139], ['Westminster, MA', 7277], ['Northborough, MA', 14155], ['Concord, MA', 17668], ['Lunenburg, MA', 10086], ['Ayer, MA', 7427], ['Shirley, MA', 7211], ['Windham, CT', 25268], ['Marlborough, CT', 6404], ['Ledyard, CT', 15051], ['West Brookfield, MA', 3701], ['Lynn, MA', 90329], ['Manchester-by-the-Sea, MA', 5136], ['Plainville, CT', 17716], ['Haddam, CT', 8346]]
# rearranging to put towns and populations in separate lists
pop_towns, pop_populations = list(zip(*pop_data))
# pop_towns is a list of strings of the form "[TOWN NAME], [STATE]"
# pop_populations is a list of integers

# %% [markdown]
# ## Problem 1
#
# Count the number of cities with populations that are greater than 50000.

# %%
# define the function here
# should return a number
def problem1(populations):
    """
    the function takes a parameter populations (list of numbers)
    and return number of populations greater than 50000 (integer)
    """
    # initial counter
    count = 0
    # initial value measure with population 
    measure = 50000
    # loop through list with populations
    for i in populations:
        # if population greater than measure
        if i > measure:
            # add to count 1
            count += 1
    # return count populations greater than 50000
    return count

# now call the function
problem1(pop_populations)
# Out:
# 48

# %% [markdown]
# ## Problem 2
#
# Find the mean population of all the given towns. Then find how many towns have a population within 3000 (plus or minus) of that number.

# %%
# define the function here
# should return a number
def problem2(populations, diff=3000):
    """
    The function takes parameter populations (list of numbers),
    finds the mean population and quantity towns have a population
    within 3000 (plus or minus) of mean.
    Returns number (integer)
    """
    # find mean population
    mean = sum(populations)/len(populations)
    # define counter with value 0
    counter = 0
    # for each population in list
    for i in populations:
        # if population is in interval mean +- diff
        if (mean - diff) < i < (mean + diff):
            # increase counter by 1
            counter += 1
    return counter

# now call the function
problem2(pop_populations)
# Out:
# 55

# %% [markdown]
# ## Problem 3
#
# How many of the towns in the dataset are in Rhode Island (RI)?

# %%
# define the function here
# should return a number
def problem3(towns, st_abbrv='RI'):
    """
    Function finds how many of the towns 
    in the dataset are in Rhode Island.
    Takes one parameter towns (list of strings)
    and returns number (integer)
    """
    # define counter with value 0 
    counter = 0
    # for each town in list of towns
    for town in towns:
        # if town in RI
        if town.endswith(st_abbrv):
            # increase counter by 1
            counter += 1
    return counter 

# now call the function
problem3(pop_towns)
# Out:
# 39

# %% [markdown]
# ## Problem 4
#
# What is the **number** of **unique** town names in the towns list when the state is not considered.

# %%
# define the function here
# should return a number
def problem4(towns):
    """
    Function takes parameter towns (list of strings)
    and finds number of unique town names.
    Return number (integer)
    """
    # define empty list uniques to store here fuond towns
    uniques = []
    # for each tjwn in towns
    for town in towns:
        # split by ',' to separate town's name from state
        town = town.split(', ')
        # if towns name was found in first time
        if town[0] not in uniques:
            # add it to list uniques
            uniques.append(town[0])
    
    # return length of list uniques that is count of all unique town's names
    return len(uniques) 

# now call the function
problem4(pop_towns)
# Out:
# 510

# %% [markdown]
# ## Problem 5
#
# What is the name of the town with the smallest population in this dataset?

# %%
# define the function here
# should return a string
def problem5(towns, populations):
    """
   The function takes two parameters towns (list of strings)
   and populations (list of numbers). Finds name of the town with the smallest population.
   Return (string)
   """
    # add code here
    # find smallest number in list of populations and it's index
    index = populations.index(min(populations))
    # return town from list of towns by this index
    return towns[index]

# now call the function
problem5(pop_towns, pop_populations)
# Out:
# 'Gosnold, MA'

# %% [markdown]
# ## Extra Credit
#
# Compute all town names that appear in **exactly two** states in this dataset.

# %%
# define the function here
# should return a **list**
def extra_credit(towns):
    """
    Function takes one parameter towns (list of strings),
    finds all town names that appear in exactly two states.
    Return list of strings
    """
    # add code here
    # define empty dict dict_towns to store towns(keys) and states(values)
    dict_towns = {}
    # efine empty list _towns to store found towns
    _towns = []
    # for each town
    for town in towns:
        # find name and state of town
        name, state = town.split(', ')
        # if town not in dict_towns
        if name not in dict_towns:
            # store it in dict as key and state as value
            dict_towns[name] = [state]
        # if name in dict
        else:
            # add to it's values new state
            dict_towns[name].append(state)
    # for each town in dict
    for town in dict_towns:
        # if town appears in two states
        if len(dict_towns[town]) == 2:
            # append it to list _towns
            _towns.append(town)
    return _towns 

# now call the function
extra_credit(pop_towns)
# Out:
# ['Westport',
#  'Cheshire',
#  'Sharon',
#  'Chester',
#  'Hopkinton',
#  'Salisbury',
#  'Winchester',
#  'Weston',
#  'Bolton',
#  'Warwick',
#  'Franklin',
#  'Plainfield',
#  'Washington',
#  'Bristol',
#  'Clinton',
#  'Berlin',
#  'Oxford',
#  'Mansfield',
#  'Plymouth',
#  'Milford',
#  'Avon',
#  'Brookfield',
#  'Watertown',
#  'Groton',
#  'Windsor',
#  'Canton',
#  'Essex',
#  'Bridgewater',
#  'Sterling',
#  'Tolland',
#  'Middletown',
#  'Easton',
#  'Andover',
#  'Granby',
#  'Salem',
#  'Scituate',
#  'Monroe',
#  'Norfolk',
#  'Goshen',
#  'Lincoln',
#  'Burlington',
#  'Middlefield',
#  'Plainville',
#  'Marlborough',
#  'Coventry',
#  'Orange',
#  'Richmond']

# %% [markdown]
# ## Check your work

# %%
import hashlib
import unittest
import sys
class TestAssignment(unittest.TestCase):
    def setUp(self):
        self.pop_data = [['Westport, CT', 26391], ['Fairfield, CT', 59404], ['Old Saybrook, CT', 10242], ['Springfield, MA', 153060], ['Thomaston, CT', 7887], ['Willington, CT', 6041], ['Cheshire, MA', 3235], ['Sturbridge, MA', 9268], ['Melrose, MA', 26983], ['Glastonbury, CT', 34427], ['Granville, MA', 1566], ['Exeter, RI', 6425], ['Colchester, CT', 16068], ['Erving, MA', 1800], ['Westerly, RI', 22787], ['Greenwich, CT', 61171], ['Suffield, CT', 15735], ['Sharon, CT', 2782], ['Douglas, MA', 8471], ['Egremont, MA', 1225], ['Chester, MA', 1337], ['Portsmouth, RI', 17389], ['North Adams, MA', 13708], ['Vernon, CT', 29179], ['Halifax, MA', 7518], ['Stonington, CT', 18545], ['Hopkinton, MA', 14925], ['Salisbury, CT', 3741], ['Winchester, CT', 11242], ['East Granby, CT', 5148], ['Smithfield, RI', 21430], ['East Windsor, CT', 11162], ['Woburn, MA', 38120], ['Westford, MA', 21951], ['Weston, MA', 11261], ['East Providence, RI', 47037], ['Waterbury, CT', 110366], ['Great Barrington, MA', 7104], ['Westfield, MA', 41094], ['Tewksbury, MA', 28961], ['Dracut, MA', 29457], ['Danbury, CT', 80893], ['Holliston, MA', 13547], ['Wendell, MA', 848], ['Abington, MA', 15985], ['Chatham, MA', 6125], ['New Haven, CT', 129779], ['Lakeville, MA', 10602], ['Sutton, MA', 8963], ['Bolton, MA', 4897], ['Maynard, MA', 10106], ['Warwick, MA', 780], ['Wakefield, MA', 24932], ['Franklin, CT', 1922], ['Plainfield, MA', 648], ['Mendon, MA', 5839], ['Glocester, RI', 9746], ['Everett, MA', 41667], ['Easthampton, MA', 16053], ['Union, CT', 854], ['Malden, MA', 59450], ['Washington, MA', 538], ['Ellington, CT', 15602], ['Pembroke, MA', 17837], ['Hancock, MA', 717], ['Salisbury, MA', 8283], ['Carlisle, MA', 4852], ['Somerville, MA', 75754], ['Bedford, MA', 13320], ['Randolph, MA', 32112], ['Wolcott, CT', 16680], ['Groveland, MA', 6459], ['Shelton, CT', 39559], ['Ashburnham, MA', 6081], ['Weymouth, MA', 53743], ['Enfield, CT', 44654], ['West Boylston, MA', 7669], ['Uxbridge, MA', 13457], ['Carver, MA', 11509], ['Belmont, MA', 24729], ['Danvers, MA', 26493], ['Savoy, MA', 692], ['Whately, MA', 1496], ['Becket, MA', 1779], ['Hingham, MA', 22157], ['Westhampton, MA', 1607], ['Cromwell, CT', 14005], ['North Andover, MA', 28352], ['Bristol, RI', 22954], ['Dalton, MA', 6756], ['Cummington, MA', 872], ['North Providence, RI', 32078], ['Westborough, MA', 18272], ['Medfield, MA', 12024], ['Little Compton, RI', 3492], ['West Haven, CT', 55564], ['Tisbury, MA', 3949], ['Clarksburg, MA', 1702], ['Leominster, MA', 40759
Granby, MA', 6240], ['Harvard, MA', 6520], ['West Warwick, RI', 29191], ['Heath, MA', 706], ['Burlington, CT', 9301], ['Stoughton, MA', 26962], ['Mansfield, MA', 23184], ['Petersham, MA', 1234], ['West Hartford, CT', 63268], ['Darien, CT', 20732], ['Essex, CT', 6683], ['Beverly, MA', 39502], ['East Greenwich, RI', 13146], ['Hadley, MA', 5250], ['Hubbardston, MA', 4382], ['Tolland, CT', 15052], ['Madison, CT', 18269], ['Hanson, MA', 10209], ['Watertown, MA', 31915], ['Duxbury, MA', 15059], ['North Canaan, CT', 3315], ['Hampton, CT', 1863], ['Meriden, CT', 60868], ['Boxford, MA', 7965], ['Cohasset, MA', 7542], ['Newton, MA', 85146], ['Mattapoisett, MA', 6045], ['Hartland, CT', 2114], ['Huntington, MA', 2180], ['Richmond, MA', 1475], ['Winchester, MA', 21374], ['Guilford, CT', 22375], ['Hampden, MA', 5139], ['Westminster, MA', 7277], ['Northborough, MA', 14155], ['Concord, MA', 17668], ['Lunenburg, MA', 10086], ['Ayer, MA', 7427], ['Shirley, MA', 7211], ['Windham, CT', 25268], ['Marlborough, CT', 6404], ['Ledyard, CT', 15051], ['West Brookfield, MA', 3701], ['Lynn, MA', 90329], ['Manchester-by-the-Sea, MA', 5136], ['Plainville, CT', 17716], ['Haddam, CT', 8346]]
        self.towns, self.populations = list(zip(*self.pop_data))        

    def test_problem1(self):
        res = problem1(self.populations)
        hashed_res = hashlib.sha1(str(res).encode('utf-8')).hexdigest()
        self.assertEqual(hashed_res, '64e095fe763fc62418378753f9402623bea9e227')
        
    def test_problem2(self):
        res = problem2(self.populations)
        hashed_res = hashlib.sha1(str(res).encode('utf-8')).hexdigest()
        self.assertEqual(hashed_res, '8effee409c625e1a2d8f5033631840e6ce1dcb64')

    def test_problem3(self):
        res = problem3(self.towns)
        hashed_res = hashlib.sha1(str(res).encode('utf-8')).hexdigest()
        self.assertEqual(hashed_res, 'ca3512f4dfa95a03169c5a670a4c91a19b3077b4')
    
    def test_problem4(self):
        res = problem4(self.towns)
        hashed_res = hashlib.sha1(str(res).encode('utf-8')).hexdigest()
        self.assertEqual(hashed_res, '2d3fbcffe8a44d7f02a2b8c374085b84f0284201')
    
    def test_problem5(self):
        res = problem5(self.towns, self.populations)
        hashed_res = hashlib.sha1(str(res).encode('utf-8')).hexdigest()
        self.assertEqual(hashed_res, '48507d35b6ef4893f5ad4043a5acb3aebff93219')

    def test_extra_credit(self):
        res = extra_credit(self.towns)
        hashed_res = hashlib.sha1(str(list(sorted(res))).encode('utf-8')).hexdigest()
        self.assertEqual(hashed_res, 'f86b98515b9efc7ae66c39393774f02b1f90e8df')

suite = unittest.TestLoader().loadTestsFromModule(TestAssignment())
unittest.TextTestRunner(stream=sys.stdout).run(suite)
# Out:
# ......
# ----------------------------------------------------------------------
# Ran 6 tests in 0.049s
#
# OK
# <unittest.runner.TextTestResult run=6 errors=0 failures=0>
